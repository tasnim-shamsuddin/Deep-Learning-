# %% [markdown]
# <a href="https://colab.research.google.com/github/tasnim-shamsuddin/Deep-Learning-/blob/main/DeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
pd.read_csv("/content/aps_data.csv")
# Out:
# /tmp/ipython-input-1347630507.py:1: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("/content/aps_data.csv")
#      class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0      neg       6      0           0      0      0      0      0      0
# 1      neg      90      0           0     66      0      0      0      0
# 2      neg      30     na          16     14      0      0      0      0
# 3      neg     444     na          14     12      0      0      0      0
# 4      neg      82     na          12     10      0      0      0      0
# ...    ...     ...    ...         ...    ...    ...    ...    ...    ...
# 4995   neg   31394     na           0     na      0      0      0      0
# 4996   neg    1598     na           0     na      0      0      0      0
# 4997   neg      42      2  2130706454     56      0      0      0      0
# ...

# %%
! git clone https://github.com/tasnim-shamsuddin/Deep-Learning-.git
# Out:
# Cloning into 'Deep-Learning-'...
# ...
